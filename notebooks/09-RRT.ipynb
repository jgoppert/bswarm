# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Rapidly Exploring Random Trees (RRT)
#
# For more information:
#
# * [Wikipedia](https://en.wikipedia.org/wiki/Rapidly-exploring_random_tree)
# * [Modern Robotics Textbook](http://hades.mech.northwestern.edu/images/7/7f/MR.pdf)
#
# This notebook shows how to code an RRT for a vehicle described by the SE2 group.
#
# The python cdoe is here [Python](rrt.py)

# %%
import rrt

X_start = rrt.SE2_from_param([0, 1, 0])  # theta=0, x=0, y=0
X_goal = rrt.SE2_from_param([0, 8, 0])  # theta=0, x=10, y=0

# this is a list of all obstacles
# x, y, radius
collision_points = [
    [5, 0, 1],
    [2, 4, 1],
    [5, -5, 2],
    [10, 5, 3],
    [10, -5, 1],
]

ret = rrt.rrt(X_start=X_start, X_goal=X_goal, vehicle_radius=1,
        box=[0, 10, -5, 5], collision_points=collision_points,
        plot=True, max_iterations=500, dist_plan=3, tolerance=0.5)
print('success', ret['success'])
# Out:
# success True

# %% [markdown]
# Return returns a path that is a list of tree nodes.

# %%
ret['path'][0].position
# Out:
# array([[ 1., -0.,  1.],
#        [ 0.,  1.,  0.],
#        [ 0.,  0.,  1.]])
